# %%
from clickhouse_driver import Client
import io
import pandas as pd
import numpy as np
from pymongo import MongoClient
from bson.objectid import ObjectId
import datetime
import psycopg2
import requests
import json
import time
from requests_futures.sessions import FuturesSession
from backend_logic import *
session = FuturesSession()

offerid = '5d03c6207e7680141c2a2cf1'
maxRivalsCount = 10
sqiDiffCoef = 100
maxPos = 10
minCountInSerm = 6

keywords, rivals, startDate, keywordsStr, regionsStr, regions = getRivalsAndData(offerid, maxRivalsCount, sqiDiffCoef, maxPos, minCountInSerm)
rivals
# Out:
# [{'domain': 'ozon.ru',
#   'countInSerm': 4262,
#   'isExcluded': True,
#   'sqi': (34000,),
#   'isOfferDomain': False,
#   'sqiDiff': 68.0},
#  {'domain': 'wildberries.ru',
#   'countInSerm': 3589,
#   'isExcluded': True,
#   'sqi': (40000,),
#   'isOfferDomain': False,
#   'sqiDiff': 80.0},
#  {'domain': 'market.yandex.ru',
#   'countInSerm': 2587,
#   'isExcluded': True,
#   'sqi': (1000000,),
#   'isOfferDomain': False,
#   'sqiDiff': 2000.0},
#  {'domain': 'moskva.regmarkets.ru',
#   'countInSerm': 2371,
#   'isExcluded': True,
#   'sqi': (5400,),
#   'isOfferDomain': False,
#   'sqiDiff': 10.8},
#  {'domain': 'moskva.tiu.ru',
#   'countInSerm': 2203,
#   'isExcluded': True,
#   'sqi': (17000,),
#   'isOfferDomain': False,
#   'sqiDiff': 34.0},
#  {'domain': 'ru.aliexpress.com',
#   'countInSerm': 1893,
#   'isExcluded': True,
#   'sqi': (77000,),
#   'isOfferDomain': False,
#   'sqiDiff': 154.0},
#  {'domain': 'tiu.ru',
#   'countInSerm': 1770,
#   'isExcluded': True,
#   'sqi': (17000,),
#   'isOfferDomain': False,
#   'sqiDiff': 34.0},
#  {'domain': 'moskva.satom.ru',
#   'countInSerm': 1510,
#   'isExcluded': True,
#   'sqi': (4700,),
#   'isOfferDomain': False,
#   'sqiDiff': 9.4},
#  {'domain': 'sima-land.ru',
#   'countInSerm': 1413,
#   'isExcluded': True,
#   'sqi': (13000,),
#   'isOfferDomain': False,
#   'sqiDiff': 26.0},
#  {'domain': 'dns-shop.ru',
#   'countInSerm': 1171,
#   'isExcluded': True,
#   'sqi': (34000,),
#   'isOfferDomain': False,
#   'sqiDiff': 68.0},
#  {'domain': 'fismart.ru',
#   'countInSerm': 0,
#   'isExcluded': False,
#   'sqiDiff': 1.0,
#   'sqi': (500,),
#   'isOfferDomain': True}]

# %%
import codecs
with codecs.open('rivals.json', 'r', encoding='utf-8') as f:
    file = f.readlines()
    rivals = json.loads(file[0])
rivals
# Out:
# [{'domain': 'ozon.ru',
#   'countInSerm': 4262,
#   'isExcluded': True,
#   'sqi': [34000],
#   'isOfferDomain': False,
#   'sqiDiff': 68,
#   'title': 'OZON — интернет-магазин. Миллионы товаров по выгодным ценам',
#   'description': 'Интернет-магазин OZON — низкие цены на миллионы товаров! Электроника, одежда, косметика, книги, зоотовары, продукты и многое другое. Быстрая доставка на дом, в пункты выдачи или почтоматы.',
#   'icon': 'http://ozon.ru/public/favicon.ico'},
#  {'domain': 'wildberries.ru',
#   'countInSerm': 3589,
#   'isExcluded': True,
#   'sqi': [40000],
#   'isOfferDomain': False,
#   'sqiDiff': 80,
#   'title': '\n        WildBerries.ru – Интернет-магазин модной одежды и обуви\n    ',
#   'description': 'Коллекции женской, мужской и детской одежды, обуви, а также товары для дома и спорта. Информация о доставке и оплате. Таблицы размеров, советы по уходу за вещами.',
#   'icon': 'http://wildberries.ru/favicon.ico'},
#  {'domain': 'market.yandex.ru',
#   'countInSerm': 2587,
#   'isExcluded': True,
#   'sqi': [1000000],
#   'isOfferDomain': False,
#   'sqiDiff': 2000,
#   'title': 'Яндекс.Маркет — выбор и покупка товаров из проверенных интернет-магазинов',
#   'description': 'Яндекс.Маркет поможет найти и купить подходящий товар по выгодной цене: рейтинги, отзывы и разнообразные фильтры сориентируют среди миллионов предложений интернет-магазинов.',
#   'icon': 'http://market.yandex.ru//yastatic.net/market-export/_/i/favicon.ico'},
#  {'domain': 'moskva.regmarkets.ru',
#   'countInSerm': 2371,
#   'isExcluded': True,
#   'sqi': [5400],
#   'isOfferDomain': False,
#   'sqiDiff': 10.8,
#   'title': 'Крупнейший каталог товаров в Москве - moskva.regmarkets.ru',
#   'description': '',
#   'icon': 'http://moskva.regmarkets.ru/favicon.ico'},
#  {'domain': 'moskva.tiu.ru',
#   'countInSerm': 2203,
#   'isExcluded': True,
#   'sqi': [17000],
#   'isOfferDomain': False,
#   'sqiDiff': 34,
#   'title': 'Товары и услуги в Москве — портал Moskva.tiu.ru',
#   'description': 'Tiu.ru — товары и услуги в Москве. Потребительские, промышленные и оптовые товары - все для вашего бизнеса, быта и отдыха!',
#   'icon': 'https://uaprom-static.c2.prom.st/image/portal/icons/favicon.ico?rev=ab5c67f1ef2f86052547436361d8369e61449e60'},
#  {'domain': 'ru.aliexpress.com',
#   'countInSerm': 1893,
#   'isExcluded': True,
#   'sqi': [77000],
#   'isOfferDomain': False,
#   'sqiDiff': 154,
#   'title': 'AliExpress.com - интернет-магазин электроники, модных новинок, товаров для дома и сада, игрушек, товаров для спорта, автотоваров и многого другого.',
#   'description': 'Интернет-магазин электроники, модных новинок, телефонов и аксессуаров, компьютерной электроники, игрушек и многого другого.',
#   'icon': 'http://ru.aliexpress.com//ae01.alicdn.com/images/eng/wholesale/icon/aliexpress.ico'},
#  {'domain': 'tiu.ru',
#   'countInSerm': 1770,
#   'isExcluded': True,
#   'sqi': [17000],
#   'isOfferDomain': False,
#   'sqiDiff': 34,
#   'title': 'Tiu.ru — маркетплейс России',
#   'description': 'Tiu.ru — одна из крупнейших торговых площадок России. Потребительские, промышленные и оптовые товары. Все для вашего бизнеса, быта и отдыха!',
#   'icon': 'https://uaprom-static.c2.prom.st/image/portal/icons/favicon.ico?rev=ab5c67f1ef2f86052547436361d8369e61449e60'},
#  {'domain': 'moskva.satom.ru',
#   'countInSerm': 1510,
#   'isExcluded': True,
#   'sqi': [4700],
#   'isOfferDomain': False,
#   'sqiDiff': 9.4,
#   'title': 'Satom.ru - каталог интернет-магазинов, товаров, услуг и цен Москвы',
#   'description': '100 000 интернет-магазинов, 8 753 000 товаров и 47 000 услуг Москвы с актуальными ценами. Крупнейший каталог сайтов товаров и услуг - Satom.ru',
#   'icon': 'http://moskva.satom.ru/pics/favicons/apple-icon-57x57.png'},
#  {'domain': 'sima-land.ru',
#   'countInSerm': 1413,
#   'isExcluded': True,
#   'sqi': [13000],
#   'isOfferDomain': False,
#   'sqiDiff': 26,
#   'title': '«Сима-ленд» — Сувениры оптом | Купить подарки в интернет магазине | Москва, Екатеринбург, Санкт-Петербург',
#   'description': 'Интернет магазин Сима-ленд - купить сувениры и подарки оптом и в розницу. Огромный каталог - более 500 000 наименований для поставок в Москву, Екатеринбург, Санкт-Петербург, по России, странам СНГ и Европе',
#   'icon': 'https://static2.static1-sima-land.com/favicon/apple-touch-icon-144x144.png'},
#  {'domain': 'dns-shop.ru',
#   'countInSerm': 1171,
#   'isExcluded': True,
#   'sqi': [34000],
#   'isOfferDomain': False,
#   'sqiDiff': 68,
#   'title': 'DNS – интернет магазин цифровой и бытовой техники по доступным ценам.',
#   'description': 'Большой ассортимент электроники, цифровой и бытовой техники, а так же товаров для дома, известных брендов в интернет-магазине DNS по отличным ценам. Гарантия и сервис. Доставка!',
#   'icon': 'https://as.dns-shop.ru/assets/8c861ad8/images/theme/favicon.png'},
#  {'domain': 'irecommend.ru',
#   'countInSerm': 1134,
#   'isExcluded': True,
#   'sqi': [14000],
#   'isOfferDomain': False,
#   'sqiDiff': 28,
#   'title': 'IRecommend.ru | Отзывы покупателей',
#   'description': 'Отзывы о товарах и услугах, уникальные фото, опыт владельцев! Читайте отзывы реальных людей!',
#   'icon': 'http://irecommend.ru/themes/irecommend_new/images/favicon.png?v=1'},
#  {'domain': 'avito.ru',
#   'countInSerm': 1132,
#   'isExcluded': True,
#   'sqi': [110000],
#   'isOfferDomain': False,
#   'sqiDiff': 220,
#   'title': 'Авито — объявления в Туле ',
#   'description': 'Выгодно покупайте и продавайте авто, недвижимость и вещи в Туле. Находите надёжных исполнителей и работу. Самый популярный сервис объявлений в России.',
#   'icon': 'https://www.avito.st/s/common/touch-icons/common/apple-touch-icon-180x180-precomposed.png?57be3fb'},
#  {'domain': 'eldorado.ru',
#   'countInSerm': 1042,
#   'isExcluded': True,
#   'sqi': [22000],
#   'isOfferDomain': False,
#   'sqiDiff': 44,
#   'title': 'Эльдорадо - интернет-магазин электроники, цифровой и бытовой техники, выгодные цены, доставка по Москве и регионам.',
#   'description': 'Интернет магазин Эльдорадо: широкий ассортимент электроники, цифровой и бытовой техники с доставкой на дом и самовывозом из магазинов Эльдорадо по всей России. Качество по лучшей цене!',
#   'icon': 'http://eldorado.ru/favicon.ico'},
#  {'domain': 'otzovik.com',
#   'countInSerm': 898,
#   'isExcluded': True,
#   'sqi': [15000],
#   'isOfferDomain': False,
#   'sqiDiff': 30,
#   'title': '',
#   'description': '',
#   'icon': 'http://otzovik.com/favicon.ico'},
#  {'domain': 'mvideo.ru',
#   'countInSerm': 855,
#   'isExcluded': True,
#   'sqi': [30000],
#   'isOfferDomain': False,
#   'sqiDiff': 60,
#   'title': '403 Forbidden',
#   'description': '',
#   'icon': 'http://mvideo.ru/favicon.ico'},
#  {'domain': 'auchan.ru',
#   'countInSerm': 839,
#   'isExcluded': False,
#   'sqi': [7000],
#   'isOfferDomain': False,
#   'sqiDiff': 14,
#   'title': 'АШАН интернет-магазин - более 80 000 товаров по выгодным ценам | Товары для дома и дачи, игрушки, электроника, одежда, бытовая техника',
#   'description': 'В интернет магазине Ашан широкий ассортимент товаров для детей, дома, дачи. Вы можете купить в интернете любые товары по самым выгодным ценам. Пункты самовывоза и доставка по всей территории России. Мы гарантируем высокое качество и удобство покупок онлайн.',
#   'icon': 'https://www.auchan.ru/pokupki/skin/frontend/enterprise/auchan/favicon.ico'},
#  {'domain': 'onlinetrade.ru',
#   'countInSerm': 716,
#   'isExcluded': False,
#   'sqi': [13000],
#   'isOfferDomain': False,
#   'sqiDiff': 26,
#   'title': '',
#   'description': '',
#   'icon': 'http://onlinetrade.ru/favicon.ico'},
#  {'domain': 'msk.blizko.ru',
#   'countInSerm': 692,
#   'isExcluded': True,
#   'sqi': [5800],
#   'isOfferDomain': False,
#   'sqiDiff': 11.6,
#   'title': '\nBLIZKO Москва - Портал товаров и услуг. Покупайте и продавайте здесь\n',
#   'description': 'BLIZKO поможет сделать выбор, если вы делаете ремонт, готовитесь к празднику, выбираете, где сделать маникюр или вылечить зубы. Большой выбор предложений на все случаи жизни. Для легкого выбора воспользуйтесь удобным каталогом, выбором товаров по характеристикам или поиском. Читайте отзывы о компаниях и товарах, следите за акциями. Выбирать и совершать покупки на портале BLIZKO быстро и легко, попробуйте!',
#   'icon': 'https://stblizko.ru/assets/favicon/favicon-c90f676e104cf8a201ecba97d4948707.ico'},
#  {'domain': 'posuda-prof.ru',
#   'countInSerm': 652,
#   'isExcluded': False,
#   'sqi': [130],
#   'isOfferDomain': False,
#   'sqiDiff': 0.26,
#   'title': 'Интернет-магазин посуды, купить посуду в Москве по низким ценам',
#   'description': 'Магазин посуды и бытовой техники-мы сделаем вашу жизнь комфортной!',
#   'icon': 'http://posuda-prof.ru/favicon.ico?1478541567'},
#  {'domain': 'my-shop.ru',
#   'countInSerm': 615,
#   'isExcluded': True,
#   'sqi': [11000],
#   'isOfferDomain': False,
#   'sqiDiff': 22,
#   'title': 'My-shop.ru — Интернет-магазин: книги, учебники, игрушки, канцтовары, подарки, видео, музыка, софт и др. товары',
#   'description': 'Интернет-магазин My-shop.ru - это книжный магазин, магазин игрушек и детских товаров, интернет-магазин учебников и учебной литературы, а также магазин подарков, канцелярских товаров, музыки, софта и фильмов, товаров для сада и огорода. Скидки до 25%.',
#   'icon': 'http://my-shop.ru/favicon.ico'},
#  {'domain': 'top-shop.ru',
#   'countInSerm': 599,
#   'isExcluded': False,
#   'sqi': [3400],
#   'isOfferDomain': False,
#   'sqiDiff': 6.8,
#   'title': 'Top Shop – интернет-магазин оригинальных товаров',
#   'description': 'Интернет-магазин Top Shop (Топ Шоп) предлагает широкий ассортимент товаров по доступным ценам. Сезонные распродажи, скидки, акции и подарки. Доставка в любой регион России. Ознакомьтесь с каталогом товаров и текущими акциями прямо сейчас.',
#   'icon': 'http://top-shop.ru/favicon/apple-icon-57x57.png'},
#  {'domain': 'goodster.ru',
#   'countInSerm': 590,
#   'isExcluded': True,
#   'sqi': [2700],
#   'isOfferDomain': False,
#   'sqiDiff': 5.4,
#   'title': 'Goodster – поиск выгодных цен',
#   'description': 'Гудстер (Goodster) знает,  где народ дешевле покупает :) 228 765 374 предложений от 24 743 магазинов на одном сайте. Выбери свой товар в 2 клика по выгодной цене. ⭐ ◉ ✅',
#   'icon': 'http://goodster.ru/favicon.ico'},
#  {'domain': 'ikea.com',
#   'countInSerm': 535,
#   'isExcluded': True,
#   'sqi': [16000],
#   'isOfferDomain': False,
#   'sqiDiff': 32,
#   'title': 'IKEA.com â\x80\x93 International homepage â\x80\x93 IKEA',
#   'description': "IKEA furniture and home accessories are practical, well designed and affordable. Here you can find your country's IKEA website and more about the IKEA business idea.",
#   'icon': 'http://ikea.com/ext/ikeagateway/statics/apple-touch-icon.png'},
#  {'domain': 'mrdom.ru',
#   'countInSerm': 521,
#   'isExcluded': False,
#   'sqi': [950],
#   'isOfferDomain': False,
#   'sqiDiff': 1.9,
#   'title': 'Интернет-магазин товаров для дома — купить полезные и недорогие товары для дома, дачи и сада в каталоге гипермаркета №1 Мистер Дом',
#   'description': 'Более 100 000 товаров для дома, дачи и сада в наличии. ✔ Нет минимальной стоимости заказа ✔ Обмен/возврат без лишних вопросов. ✔ Доставка по Москве и всей России.',
#   'icon': 'http://mrdom.ru/favicon.ico'},
#  {'domain': 'hoff.ru',
#   'countInSerm': 507,
#   'isExcluded': True,
#   'sqi': [7300],
#   'isOfferDomain': False,
#   'sqiDiff': 14.6,
#   'title': 'Hoff: гипермаркет мебели и товаров для дома, интернет-магазин мебели',
#   'description': 'Мебель и товары для дома в интернет-магазине Hoff. Более 10 тысяч моделей по ценам производителя в наличии и под заказ; доставка, сборка, гарантия качества.',
#   'icon': 'http://hoff.ru/local/templates/redesign/frontend/dist/favicon.ico'},
#  {'domain': 'posudamart.ru',
#   'countInSerm': 490,
#   'isExcluded': False,
#   'sqi': [550],
#   'isOfferDomain': False,
#   'sqiDiff': 1.1,
#   'title': 'Купить посуду в гипермаркете посуды Posudamart  - выбирайте!',
#   'description': 'Интернет-магазин PosudaMart - это огромный выбор кухонной и столовой посуды - недорогие и премиальные варианты, быстрая доставка по Москве и РФ.',
#   'icon': 'http://posudamart.ru/favicon.ico'},
#  {'domain': 'yavitrina.ru',
#   'countInSerm': 477,
#   'isExcluded': True,
#   'sqi': [1400],
#   'isOfferDomain': False,
#   'sqiDiff': 2.8},
#  {'domain': 'msk.yavitrina.ru',
#   'countInSerm': 437,
#   'isExcluded': True,
#   'sqi': [1400],
#   'isOfferDomain': False,
#   'sqiDiff': 2.8},
#  {'domain': 'posudamoskva.ru',
#   'countInSerm': 435,
#   'isExcluded': False,
#   'sqi': [130],
#   'isOfferDomain': False,
#   'sqiDiff': 0.26,
#   'title': 'Интернет магазин посуды в Москве, доступные цены, большой каталог - posudamoskva.ru',
#   'description': 'Интернет магазин Posudamoskva.ru - это большой выбор посуды по выгодным ценам. Осуществляем доставку по Москве и всей России.',
#   'icon': 'http://posudamoskva.ru/favicon.ico'},
#  {'domain': 'yamart.ru',
#   'countInSerm': 431,
#   'isExcluded': True,
#   'sqi': [700],
#   'isOfferDomain': False,
#   'sqiDiff': 1.4,
#   'title': 'Крупнейший каталог товаров в России - yamart.ru',
#   'description': 'Yamart.ru - это товарный агрегатор, объединяющий более 100 млн. товаров от 35 000 продавцов в Москве',
#   'icon': 'http://yamart.ru/favicon.ico'},
#  {'domain': 'eco-skovoroda.ru',
#   'countInSerm': 412,
#   'isExcluded': False,
#   'sqi': [240],
#   'isOfferDomain': False,
#   'sqiDiff': 0.48,
#   'title': 'Интернет-магазин сковородок ЭКО-Сковорода.ру: купить сковороду выгодно с бесплатной доставкой',
#   'description': 'Специализированный интернет-магазин сковородок из Италии, России, Кореи: каменные сковороды и сковороды с каменным покрытием, керамические сковороды и сковороды с керамическим покрытием. Широкий выбор, гарантия, скидки и акции. ЭКО-Сковорода.ру',
#   'icon': 'http://eco-skovoroda.ru/favicon.ico'},
#  {'domain': 'samura.ru',
#   'countInSerm': 411,
#   'isExcluded': True,
#   'sqi': [1100],
#   'isOfferDomain': False,
#   'sqiDiff': 2.2,
#   'title': 'Купить ножи с доставкой в Москве от интернет магазина Samura.',
#   'description': 'Интернет магазин ножей предлагает качественные ножи, которые производятся из высокоуглеродистой стали и керамики, а также аксессуары к ним. Все покупки можно сделать онлайн прямо на сайте. Доставка по всей РФ.',
#   'icon': 'http://samura.ru/favicon.ico'},
#  {'domain': 'gipfel.ru',
#   'countInSerm': 403,
#   'isExcluded': False,
#   'sqi': [350],
#   'isOfferDomain': False,
#   'sqiDiff': 0.7,
#   'title': 'Интернет-магазин посуды в Москве -  официальный сайт Gipfel (Гипфел)',
#   'description': 'Посуда Gipfel (Германия)  от производителя, в огромном ассортименте. Официальный интернет-магазин Gipfel, с доставкой по России.',
#   'icon': 'http://gipfel.ru/favicon.ico?1554380392'},
#  {'domain': 'technopark.ru',
#   'countInSerm': 391,
#   'isExcluded': True,
#   'sqi': [3800],
#   'isOfferDomain': False,
#   'sqiDiff': 7.6,
#   'title': 'Интернет-магазин бытовой техники ТЕХНОПАРК. Купить бытовую технику и электронику с доставкой и гарантией',
#   'description': 'Интернет-магазин бытовой техники и электроники Tehnopark.ru: продажа стиральных машин, телевизоров, ноутбуков, холодильников и пылесосов, низкие цены, кредит и доставка.',
#   'icon': 'http://technopark.ru/favicon.ico'},
#  {'domain': 'olive-house.ru',
#   'countInSerm': 386,
#   'isExcluded': False,
#   'sqi': [350],
#   'isOfferDomain': False,
#   'sqiDiff': 0.7,
#   'title': 'Магазин европейской посуды - olive-house.ru',
#   'description': 'Магазин европейской посуды - olive-house.ru',
#   'icon': 'http://olive-house.ru/favicon.ico'},
#  {'domain': 'leroymerlin.ru',
#   'countInSerm': 370,
#   'isExcluded': True,
#   'sqi': [13000],
#   'isOfferDomain': False,
#   'sqiDiff': 26,
#   'title': 'Леруа Мерлен – товары для строительства и ремонта в Москве по низким ценам',
#   'description': 'Мы делаем доступными для каждого ремонт и обустройство дома. Широкий ассортимент строительных товаров, выгодные цены в каталоге Леруа Мерлен.',
#   'icon': 'http://leroymerlin.ru//res.cloudinary.com/lmru/image/upload/favicon/favicon.ico'},
#  {'domain': 'vsevse.ru',
#   'countInSerm': 365,
#   'isExcluded': True,
#   'sqi': [400],
#   'isOfferDomain': False,
#   'sqiDiff': 0.8,
#   'title': 'Маркетплейс ВсёВсё.ру – все покупки в одном месте',
#   'description': 'На маркетплейсе ВсёВсё.ру представлены сотни тысяч товаров всех направлений от тысяч продавцов. Просто выберите товары и мы организуем оперативную доставку вашего заказа по всей России.',
#   'icon': 'https://www.vsevse.ru/favicon.ico'},
#  {'domain': 'posuda.ru',
#   'countInSerm': 359,
#   'isExcluded': False,
#   'sqi': [900],
#   'isOfferDomain': False,
#   'sqiDiff': 1.8,
#   'title': 'Интернет-магазин "Посуда.Ру" : посуда оптом и в розницу с доставкой по Москве, Санкт-Петербургу и всей России.',
#   'description': 'Интернет магазин посуды Posuda.ru – это посуда на любой вкус и кошелек с доставкой по Москве и всей России',
#   'icon': 'http://posuda.ru/favicon.ico'},
#  {'domain': 'best-kitchen.ru',
#   'countInSerm': 345,
#   'isExcluded': False,
#   'sqi': [400],
#   'isOfferDomain': False,
#   'sqiDiff': 0.8,
#   'title': 'Best-Kitchen.ru - лучшие товары для кухни и дома (интернет-магазин).',
#   'description': 'Best-Kitchen.ru',
#   'icon': 'https://assets3.insales.ru/assets/1/5291/1225899/1560613791/favicon.ico'},
#  {'domain': 'akusherstvo.ru',
#   'countInSerm': 340,
#   'isExcluded': True,
#   'sqi': [4300],
#   'isOfferDomain': False,
#   'sqiDiff': 8.6,
#   'title': 'Акушерство.ру - интернет-магазин детских товаров',
#   'description': 'Детские товары в интернет магазине «Акушерство». Огромный выбор колясок, игрушек, мебели, автокресел и других товаров для детей. Доставка по Москве и России.',
#   'icon': 'http://akusherstvo.ru//static.akusherstvo.ru/favicon.ico?v=7'},
#  {'domain': 'youtube.com',
#   'countInSerm': 304,
#   'isExcluded': True,
#   'sqi': [350000],
#   'isOfferDomain': False,
#   'sqiDiff': 700,
#   'title': 'YouTube',
#   'description': 'Смотрите любимые видео, слушайте любимые песни, загружайте собственные ролики и делитесь ими с друзьями, близкими и целым миром.',
#   'icon': 'https://s.ytimg.com/yts/img/favicon-vfl8qSV2F.ico'},
#  {'domain': 'e-katalog.ru',
#   'countInSerm': 304,
#   'isExcluded': True,
#   'sqi': [13000],
#   'isOfferDomain': False,
#   'sqiDiff': 26,
#   'title': 'e-Katalog - каталог товаров, сравнение цен в интернет-магазинах России',
#   'description': 'Каталог товаров E-KATALOG >>> все цены интернет-магазинов России ✔ Сравнение ✔ Отзывы ✔ Рейтинги, обзоры, видео.',
#   'icon': 'http://e-katalog.ru/img/favicon/ek-apple-touch-icon.png'},
#  {'domain': 'livemaster.ru',
#   'countInSerm': 304,
#   'isExcluded': True,
#   'sqi': [17000],
#   'isOfferDomain': False,
#   'sqiDiff': 34,
#   'title': '\t\t\tЯрмарка Мастеров - ручная работа, handmade\n\t',
#   'description': '\t\t\tНа сайте Ярмарка Мастеров (livemaster.ru) Вы найдете большой выбор одежды, украшений, кукол и игрушек ручной работы. Вы сможете подобрать интересный сувенир или порадовать себя, купив что-то для дома.\n\t',
#   'icon': 'http://livemaster.ru/favicon.ico?300620171503'},
#  {'domain': 'kazanchik.ru',
#   'countInSerm': 293,
#   'isExcluded': False,
#   'sqi': [240],
#   'isOfferDomain': False,
#   'sqiDiff': 0.48,
#   'title': 'Посуда для кухни по низким ценам | Купить в интернет-магазине Казанчик',
#   'description': 'Интернет-магазин Казанчик.ру предлагает купить недорогую посуду для кухни. Большой выбор кухонной посуды и аксессуаров! Доставка, гарантия. Акции и подарки.',
#   'icon': 'http://kazanchik.ru/favicon.ico'},
#  {'domain': 'detmir.ru',
#   'countInSerm': 291,
#   'isExcluded': True,
#   'sqi': [17000],
#   'isOfferDomain': False,
#   'sqiDiff': 34,
#   'title': 'Интернет магазин детских товаров и игрушек в Москве, игрушки и товары для детей в интернет магазине ”Детский Мир”',
#   'description': 'Интернет-магазин «Детский Мир» предлагает купить товары и игрушки для детей по выгодной цене. В нашем каталоге Вы можете выбрать и заказать детские товары и игрушки с доставкой по Москве, Санкт-Петербургу, Новосибирску и другим городам России.',
#   'icon': 'https://go.detmir.st/img/1FFdRzr.qfL2tuX0IzS_Or188.ico'},
#  {'domain': 'vidy-posudy.ru',
#   'countInSerm': 288,
#   'isExcluded': True,
#   'sqi': [70],
#   'isOfferDomain': False,
#   'sqiDiff': 0.14,
#   'title': 'Виды посуды',
#   'description': 'Энциклопедия посуды для домашних хозяек. Все виды посуды для приготовления, хранения, сервировки. Инструкции по выбору, обзоры, рекомендации.',
#   'icon': 'https://vidy-posudy.ru/wp-content/uploads/2017/12/cropped-525-150x150.png'},
#  {'domain': 'superposuda.ru',
#   'countInSerm': 272,
#   'isExcluded': False,
#   'sqi': [300],
#   'isOfferDomain': False,
#   'sqiDiff': 0.6,
#   'title': 'Интернет-магазин Суперпосуда : купить посуду в Москве, доставка по всей России',
#   'description': '',
#   'icon': 'http://superposuda.ru/favicon.ico'},
#  {'domain': 'brandshome-shop.ru',
#   'countInSerm': 255,
#   'isExcluded': False,
#   'sqi': [150],
#   'isOfferDomain': False,
#   'sqiDiff': 0.3,
#   'title': 'Необычные товары для дома. Интернет-магазин Brands Home ',
#   'description': '',
#   'icon': 'http://brandshome-shop.ruimages/favicon.ico'},
#  {'domain': 'hugmug.ru',
#   'countInSerm': 235,
#   'isExcluded': False,
#   'sqi': [120],
#   'isOfferDomain': False,
#   'sqiDiff': 0.24,
#   'title': 'Интернет-магазин термокружек, термосов, ланч боксов, фляжек и бутылок для воды. Выбрать на сайте и купить!',
#   'description': 'Интернет-магазин термокружек, термосов, ланчбоксов, бутылок, фляжек с доставкой по всей России.',
#   'icon': 'https://assets3.insales.ru/assets/1/1220/853188/1559676473/favicon.png'},
#  {'domain': 'posudatop.ru',
#   'countInSerm': 235,
#   'isExcluded': False,
#   'sqi': [90],
#   'isOfferDomain': False,
#   'sqiDiff': 0.18,
#   'title': 'Интернет магазин посуды и кухонных принадлежностей - posudatop.ru',
#   'description': 'Интернет магазин posudatop - это огромный выбор посуды по доступным ценам. Доставка по всей России.',
#   'icon': 'http://posudatop.ru/favicon.ico'},
#  {'domain': 'klenmarket.ru',
#   'countInSerm': 229,
#   'isExcluded': True,
#   'sqi': [2400],
#   'isOfferDomain': False,
#   'sqiDiff': 4.8,
#   'title': 'Профессиональное оборудование для ресторанов, кафе, баров и столовых в интернет-магазине компании КЛЕН',
#   'description': 'Широкий выбор оборудования для оснащения ресторанов и кафе в интернет-магазине КленМаркет.ру. Покупайте надежное оборудование для ресторанов и магазинов в компании КЛЕН 8 (495) 580-75-58',
#   'icon': 'http://klenmarket.ru/favicon/57.png'},
#  {'domain': 'vollmart.ru',
#   'countInSerm': 226,
#   'isExcluded': False,
#   'sqi': [230],
#   'isOfferDomain': False,
#   'sqiDiff': 0.46,
#   'title': 'Vollmart.ru – интернет магазин посуды и товаров для дома',
#   'description': 'Интернет-магазин посуды и товаров для дома vollmart.ru.  Большой каталог товаров по низким ценам, скидки, акции. Доставка на дом и самовывоз из пункта выдачи по всей России. Отправка почтой наложенным платежом.',
#   'icon': 'http://vollmart.ru/local/templates/dresscodeV2/images/favicon.png'},
#  {'domain': 'skovorodavok.ru',
#   'countInSerm': 225,
#   'isExcluded': False,
#   'sqi': [130],
#   'isOfferDomain': False,
#   'sqiDiff': 0.26,
#   'title': 'Сковорода вок казан сковороды гриль. Купить все виды воков казанов - интернет-магазин Сковорода ВОК | skovorodavok.ru - С нами легко и вкусно! ',
#   'description': 'Интернет-магазин Сковорода Вок предлагает большой выбор  казанов чугунных, сковородок вок, чугунной посуды, чугунных сковородок, сковородок гриль, кастрюль и кухонной утвари, вся продукция сертифицированна и высокого качества. Стараемся сохранять низкие цены на всю продукцию в нашем магазине. Действует гибкая система скидок. Быстрый заказ онлайн, действует доставка по Москве и всей России. Самовывоз бесплатно ',
#   'icon': 'http://skovorodavok.rufavicon.ico?v=8'},
#  {'domain': 'dochkisinochki.ru',
#   'countInSerm': 223,
#   'isExcluded': True,
#   'sqi': [8600],
#   'isOfferDomain': False,
#   'sqiDiff': 17.2,
#   'title': '«Дочки-Сыночки» – интернет-магазин детских товаров: купить детские товары в Москве',
#   'description': 'Посетите лучший магазин детских товаров! Покупайте коляски, автокресла, одежду, игрушки, мебель, средства гигиены и пр. с бесплатной доставкой в Москве. Постоянные скидки и акции. Адреса розничных магазинов.',
#   'icon': 'http://dochkisinochki.ru/apple-touch-icon.png'},
#  {'domain': 'respublica.ru',
#   'countInSerm': 214,
#   'isExcluded': True,
#   'sqi': [1900],
#   'isOfferDomain': False,
#   'sqiDiff': 3.8,
#   'title': 'Книжный интернет-магазин «Республика»',
#   'description': 'Сеть из 30 розничных магазинов книг «Республика» в Москве, Санкт-Петербурге, Новосибирске и Екатеринбурге. Доставка по всей России. В интернет-магазине можно найти и заказать интересные книги для чтения, а также товары для дома и активного образа жизни.',
#   'icon': 'http://respublica.ru/favicon.ico'},
#  {'domain': 'russian.alibaba.com',
#   'countInSerm': 212,
#   'isExcluded': True,
#   'sqi': [9000],
#   'isOfferDomain': False,
#   'sqiDiff': 18,
#   'title': 'Алибаба Alibaba - крупнейшая в мире онлайн B2B торговая платформа',
#   'description': 'Алибаба Alibaba, крупнейшая в мире онлайн B2B торговая платформа. Алибаба предлагает качественных производителей, поставщиков, экспортеров, импортеров, покупателей, оптовиков и товары. Импорт и экспорт на Alibaba.com.',
#   'icon': 'http://russian.alibaba.com//is.alicdn.com/simg/single/icon/favicon.ico'},
#  {'domain': 'belvedor.com',
#   'countInSerm': 208,
#   'isExcluded': True,
#   'sqi': [450],
#   'isOfferDomain': False,
#   'sqiDiff': 0.9,
#   'title': 'Интернет-магазин подарков и товаров для дома Бельведор. Большой каталог и низкие цены – более 1200000 товаров. Заказ от 990 руб.',
#   'description': 'Интернет-магазин Бельведор предлагает широкий ассортимент сувениров и подарков: часы, наборы для бритья, товары для детей и многое другое. Заказывайте у нас и получайте уникальные скидки. Работает доставка по России и самовывоз.',
#   'icon': 'http://belvedor.com//www.belvedor.com/favicon.ico'},
#  {'domain': 'vk.com',
#   'countInSerm': 204,
#   'isExcluded': True,
#   'sqi': [350000],
#   'isOfferDomain': False,
#   'sqiDiff': 700,
#   'title': 'Мобильная версия ВКонтакте',
#   'description': '',
#   'icon': 'http://vk.com/images/icons/favicons/fav_logo.ico?8'},
#  {'domain': 'price.ru',
#   'countInSerm': 202,
#   'isExcluded': True,
#   'sqi': [4000],
#   'isOfferDomain': False,
#   'sqiDiff': 8,
#   'title': 'Цены, товары, скидки, все интернет-магазины Тулы на Price.ru',
#   'description': 'Цены и скидки  от всех интернет-магазинов, мнения экспертов и пользователей, рейтинги магазинов и товаров  на Price.ru',
#   'icon': 'http://price.ru/favicon.ico'},
#  {'domain': 'biol.ru',
#   'countInSerm': 200,
#   'isExcluded': False,
#   'sqi': [250],
#   'isOfferDomain': False,
#   'sqiDiff': 0.5,
#   'title': 'Купить посуду БИОЛ в России - официальный интернет-магазин',
#   'description': 'ООО БИОЛ – лидирующее предприятие специализирующееся на выпуске кухонной посуды для дома и отдыха, официальное представительство в России.',
#   'icon': 'http://biol.rudesign/biol/img/favicon.ico'},
#  {'domain': 'samura-shop.ru',
#   'countInSerm': 198,
#   'isExcluded': True,
#   'sqi': [300],
#   'isOfferDomain': False,
#   'sqiDiff': 0.6,
#   'title': 'Купить кухонные ножи Cамура (Samura), стальные и керамические ножи высочайшего качества',
#   'description': 'Качественные кухонные японские ножи Samura от официального дилера. Огромный ассортимент, разумные цены, удобные способы оплаты и доставки.',
#   'icon': 'https://assets3.insales.ru/assets/1/5312/1209536/1559565116/favicon.ico'},
#  {'domain': 'nozhikov.ru',
#   'countInSerm': 197,
#   'isExcluded': True,
#   'sqi': [2200],
#   'isOfferDomain': False,
#   'sqiDiff': 4.4,
#   'title': 'Интернет-магазин ножей Nozhikov - купить фирменные и необычные ножи с доставкой по России\n',
#   'description': 'Интернет магазин ножей Ножиков - лучшие необычные и оригинальные ножи хорошего качества в Москве и СПб. Купить на официальном сайте крутые фирменные ножи по доступной цене с доставкой по России.',
#   'icon': 'https://assets3.insales.ru/assets/1/4607/1192447/1560201175/favicon.ico'},
#  {'domain': 'cookhouse.ru',
#   'countInSerm': 197,
#   'isExcluded': False,
#   'sqi': [190],
#   'isOfferDomain': False,
#   'sqiDiff': 0.38,
#   'title': 'Товары для кухни и сервировки стола: посуда и аксессуары для готовки в Москве и по всей России',
#   'description': 'Интернет-магазин COOK HOUSE - товары для кухни и кулинарные курсы. В наших магазинах можно купить товары для кухни и посуду на любой вкус - от ножей и тарелок  до грилей и кухонных комбайнов.',
#   'icon': 'http://cookhouse.ru/local/templates/main/i/favicon.ico'},
#  {'domain': 'taller.su',
#   'countInSerm': 191,
#   'isExcluded': False,
#   'sqi': [170],
#   'isOfferDomain': False,
#   'sqiDiff': 0.34},
#  {'domain': 'rezat.ru',
#   'countInSerm': 189,
#   'isExcluded': True,
#   'sqi': [1100],
#   'isOfferDomain': False,
#   'sqiDiff': 2.2,
#   'title': 'Êóïèòü ëþáûå íîæè â ãèïåðìàðêåòå íîæåé Rezat.Ru',
#   'description': 'Áîëåå 25 000 íîæåé âñåãäà èç íàëè÷èÿ â ñïåöèàëèçèðîâàííîì ìíòåðíåò ìàãàçèíå íîæåé Rezat.ru. Êàòàëîã ïî òèïàì è áðåíäàì, ðåäêèå ýêñêëþçèâíûå êîëëåêöèîííûå ìîäåëè íîæåé. Ðàñùèðåííûé ïîèñê ïî ìàòåðèàëó ñòàëè, òèïó êëèíêà.',
#   'icon': 'http://rezat.ru/favicon.ico'},
#  {'domain': 'enjoyme.ru',
#   'countInSerm': 186,
#   'isExcluded': True,
#   'sqi': [240],
#   'isOfferDomain': False,
#   'sqiDiff': 0.48,
#   'title': 'Интересные подарки, креативные дизайнерские штучки - интернет-магазин оригинальных и необычных вещей EnjoyMe',
#   'description': 'Только самые необычные подарки и смелые дизайнерские штучки от известных брендов по приятным ценам в интернет-магазине оригинальных вещей EnjoyMe',
#   'icon': 'http://enjoyme.ru/bitrix/templates/main2014/images/favicons/favicon.ico'},
#  {'domain': 'instagram.com',
#   'countInSerm': 184,
#   'isExcluded': True,
#   'sqi': [140000],
#   'isOfferDomain': False,
#   'sqiDiff': 280,
#   'title': '\nInstagram\n',
#   'description': 'Create an account or log in to Instagram - A simple, fun & creative way to capture, edit & share photos, videos & messages with friends & family.',
#   'icon': 'http://instagram.com/static/images/ico/apple-touch-icon-76x76-precomposed.png/4272e394f5ad.png'},
#  {'domain': 'moi-tvoi.ru',
#   'countInSerm': 184,
#   'isExcluded': False,
#   'sqi': [500],
#   'isOfferDomain': False,
#   'sqiDiff': 1,
#   'title': 'Moi-Tvoi.ru - Твой интернет-магазин товаров для дома и подарков по оптовым ценам',
#   'description': 'У нас Вы можете купить по выгодной цене с доставкой посуду, предметы декора и интерьера любых стилей, оригинальные подарки.',
#   'icon': 'http://moi-tvoi.ru/bitrix/templates/elektro_light/favicon.ico'},
#  {'domain': 'goods.ru',
#   'countInSerm': 183,
#   'isExcluded': True,
#   'sqi': [5200],
#   'isOfferDomain': False,
#   'sqiDiff': 10.4,
#   'title': 'Маркетплейс goods - место выгодных покупок в Москве',
#   'description': 'Маркетплейс goods.ru – это место выгодных покупок в интернет-магазинах Москвы. Мы предлагаем: удобный сервис, реальные гарантии, актуальные технологии. goods – хорошо, когда есть выбор!',
#   'icon': 'http://goods.ru/generated/img/icons/favicon.png'},
#  {'domain': 'komus.ru',
#   'countInSerm': 180,
#   'isExcluded': True,
#   'sqi': [9000],
#   'isOfferDomain': False,
#   'sqiDiff': 18,
#   'title': 'Комус – товары для офиса и бизнеса: купить канцтовары, бумагу, хозтовары, подарки и мебель',
#   'description': 'Комус - комплексная поставка товаров для офиса и бизнеса. Низкие цены и акции для малого, среднего и крупного бизнеса. Более 70 000 товаров.',
#   'icon': 'http://komus.ru/_ui/desktop/theme-komus/images/icons/favicon.ico'},
#  {'domain': 'msk.bestprice.su',
#   'countInSerm': 172,
#   'isExcluded': True,
#   'sqi': [230],
#   'isOfferDomain': False,
#   'sqiDiff': 0.46,
#   'title': 'Каталог товаров в Москве - msk.BestPrice.su',
#   'description': 'Каталог товаров в Москве. Самые выгодные предложения, цены, магазины. Рейтинг магазинов и отзывы реальных покупателей.',
#   'icon': 'http://msk.bestprice.su/favicon.ico'},
#  {'domain': 'tddomovoy.ru',
#   'countInSerm': 170,
#   'isExcluded': False,
#   'sqi': [1300],
#   'isOfferDomain': False,
#   'sqiDiff': 2.6,
#   'title': 'Интернет-магазин товаров для дома: посуда, текстиль, декоративные и хозяйственные товары',
#   'description': 'Купить товары для дома в интернет-магазине «Домовой». Широкий ассортимент. Доступные цены, акции, скидки.',
#   'icon': 'http://tddomovoy.ru/favicon.ico'},
#  {'domain': 'posudataller.ru',
#   'countInSerm': 170,
#   'isExcluded': False,
#   'sqi': [240],
#   'isOfferDomain': False,
#   'sqiDiff': 0.48,
#   'title': 'Официальный интернет-магазин посуды Taller',
#   'description': 'Официальный интернет-магазин посуды Taller',
#   'icon': 'http://posudataller.ru/bitrix/templates/dresscode/images/favicon.ico?v=1548720276'},
#  {'domain': 'rondell.ru',
#   'countInSerm': 169,
#   'isExcluded': True,
#   'sqi': [210],
#   'isOfferDomain': False,
#   'sqiDiff': 0.42,
#   'title': 'rondell.ru — Coming Soon',
#   'description': 'This is a default index page for a new domain.',
#   'icon': 'http://rondell.ru/favicon.ico'},
#  {'domain': 'nadoba-msk.ru',
#   'countInSerm': 169,
#   'isExcluded': False,
#   'sqi': [80],
#   'isOfferDomain': False,
#   'sqiDiff': 0.16,
#   'title': 'Официальный магазин Nadoba, Чехия - посуда и кухонные аксессуары с Официальной Гарантией. - Nadoba-MSK.ru',
#   'description': 'Фирменный интернет магазин посуды и кухонных аксессуаров Nadoba, Чехия. Оптовые и розничные поставки продукции Nadoba (Надоба) ',
#   'icon': 'http://nadoba-msk.ru/img/favicon.ico?1554719400'},
#  {'domain': 'zauber-rus.ru',
#   'countInSerm': 168,
#   'isExcluded': False,
#   'sqi': [90],
#   'isOfferDomain': False,
#   'sqiDiff': 0.18,
#   'title': "ZAUBER-RUS - Сайт официального дилера ZAUBER, ROSENBERG, ATLANTA, POMI'DORO",
#   'description': 'Zauber официальный сайт',
#   'icon': 'http://zauber-rus.rufavicon.ico'},
#  {'domain': 'williams-oliver.ru',
#   'countInSerm': 168,
#   'isExcluded': False,
#   'sqi': [450],
#   'isOfferDomain': False,
#   'sqiDiff': 0.9,
#   'title': 'Интернет-магазин элитной кухонной посуды для дома с доставкой - Williams Et Oliver',
#   'description': 'Интернет-магазин посуды и аксессуаров для кухни мировых брендов в Москве. Удобная кухонная посуда для ценителей кулинарного искусства. Доставка по всей России. Мы на рынке товаров для кухни уже 11 лет!',
#   'icon': 'http://williams-oliver.ru/assets/templates/default/img/apple-icons/apple-touch-icon-80x80.png'},
#  {'domain': 'posudarium.ru',
#   'countInSerm': 156,
#   'isExcluded': False,
#   'sqi': [60],
#   'isOfferDomain': False,
#   'sqiDiff': 0.12,
#   'title': 'Интернет-магазин кухонной и столовой посуды',
#   'description': 'Интернет-магазин Posudarium предлагает широкий ассортимент кухонной посуды от ведущих мировых брендов.',
#   'icon': 'http://posudarium.ru/favicon.ico'},
#  {'domain': 'mzbt.ru',
#   'countInSerm': 154,
#   'isExcluded': False,
#   'sqi': [130],
#   'isOfferDomain': False,
#   'sqiDiff': 0.26,
#   'title': 'MZBT.ru Интернет-магазин посуды',
#   'description': 'В нашем магазине представлен большой ассортимент посуды безупречного качества по наиболее выгодным ценам.',
#   'icon': 'http://mzbt.ru/favicon.ico'},
#  {'domain': 'poryadok.ru',
#   'countInSerm': 149,
#   'isExcluded': False,
#   'sqi': [2700],
#   'isOfferDomain': False,
#   'sqiDiff': 5.4,
#   'title': 'Порядок: сеть супермаркетов и интернет-магазин товаров для дома и дачи, туризма и отдыха, инструмента, детских товаров',
#   'description': 'Более 60 тысяч товаров в интернет-магазине Порядок по ценам производителя в наличии и под заказ! Товары для дома, дачи, туризма, отдыха и ремонта; инструмент, бытовая химия, товары для детей. Низкие цены, доставка курьером и самовывоз в Москве, Воронеже и всей России.',
#   'icon': 'http://poryadok.ru/favicon.ico'},
#  {'domain': 'pichshop.ru',
#   'countInSerm': 147,
#   'isExcluded': True,
#   'sqi': [1000],
#   'isOfferDomain': False,
#   'sqiDiff': 2,
#   'title': 'Интернет магазин подарков PichShop - необычные и оригинальные подарки в Москве',
#   'description': 'Интернет магазин подарков PichShop. У нас вы можете купить оригинальные и необычные подарки в Москве, Санкт-Петербурге и России',
#   'icon': 'http://pichshop.ru/bitrix/templates/main/img/favicon.png'},
#  {'domain': 'youla.ru',
#   'countInSerm': 147,
#   'isExcluded': True,
#   'sqi': [32000],
#   'isOfferDomain': False,
#   'sqiDiff': 64,
#   'title': 'Юла - доска объявлений в Туле, бесплатные частные объявления',
#   'description': 'Доска объявлений – свежие объявления частных лиц о продаже и покупке товаров всех категорий в Туле. Самый простой способ продать или купить вещи. Подать объявление бесплатно в Юле.',
#   'icon': 'http://youla.ru/apple-touch-icon-57x57.png?v382'},
#  {'domain': 'fissman.ru',
#   'countInSerm': 143,
#   'isExcluded': False,
#   'sqi': [550],
#   'isOfferDomain': False,
#   'sqiDiff': 1.1,
#   'title': 'Посуда, купить посуду для кухни, кухонная посуда недорого купить в официальном интернет-магазине FISSMAN в Москве и России.',
#   'description': '',
#   'icon': 'http://fissman.ru/local/templates/fissman/img/main/favicon.png'},
#  {'domain': 'dombutik.ru',
#   'countInSerm': 140,
#   'isExcluded': False,
#   'sqi': [190],
#   'isOfferDomain': False,
#   'sqiDiff': 0.38,
#   'title': 'Интернет магазин посуды: каталог с ценами. Купить красивую посуду в Москве на сайте Dombutik.ru',
#   'description': 'Продажа красивой посуды премиум класса в интернет магазине Домашний бутик. Оптом и в розницу. Доставка по Москве и России.',
#   'icon': 'http://dombutik.ru/favicon.ico'},
#  {'domain': 'designboom.ru',
#   'countInSerm': 140,
#   'isExcluded': True,
#   'sqi': [300],
#   'isOfferDomain': False,
#   'sqiDiff': 0.6,
#   'title': 'Интернет-магазин дизайнерских предметов интерьера и подарков',
#   'description': 'Интернет-магазин DesignBOOM.ru',
#   'icon': 'http://designboom.ru/favicon.ico'},
#  {'domain': 'kupi-skovorodu.ru',
#   'countInSerm': 135,
#   'isExcluded': True,
#   'sqi': [70],
#   'isOfferDomain': False,
#   'sqiDiff': 0.14,
#   'title': 'Сковороды - купить с доставкой по Москве. Выгодные цены на сковороды в интернет-магазине Kupi-Skovorodu.ru',
#   'description': 'Интернет-магазин Kupi-Skovorodu.ru предлагает самый широкий в Москве и России ассортимент сковород по доступным ценам. Звоните: +7 (495) 540-48-35, +7 (800) 500-90-47',
#   'icon': 'http://kupi-skovorodu.ru/favicon.ico'},
#  {'domain': 'babadu.ru',
#   'countInSerm': 135,
#   'isExcluded': True,
#   'sqi': [1200],
#   'isOfferDomain': False,
#   'sqiDiff': 2.4,
#   'title': 'Интернет магазин детских товаров Бабаду - большой выбор товаров для детей и их родителей',
#   'description': 'Игрушки, одежда, коляски, мебель, книги, косметика и многое другое для детей и их родителей',
#   'icon': 'http://babadu.ru/apple-touch-icon.png'},
#  {'domain': 'domoteka-market.ru',
#   'countInSerm': 130,
#   'isExcluded': True,
#   'sqi': [400],
#   'isOfferDomain': False,
#   'sqiDiff': 0.8,
#   'title': '403 Forbidden',
#   'description': '',
#   'icon': 'http://domoteka-market.ru/favicon.ico'},
#  {'domain': 'thermos.ru',
#   'countInSerm': 130,
#   'isExcluded': True,
#   'sqi': [150],
#   'isOfferDomain': False,
#   'sqiDiff': 0.3,
#   'title': 'Сайт официального представителя торговых марок Thermos™ и alfi в России',
#   'description': '',
#   'icon': 'http://thermos.ru/favicon.ico'},
#  {'domain': 'ulmart.ru',
#   'countInSerm': 128,
#   'isExcluded': True,
#   'sqi': [14000],
#   'isOfferDomain': False,
#   'sqiDiff': 28,
#   'title': '«Юлмарт» - Интернет-Магазин №1 в России',
#   'description': 'Интернет-платформа для комфортных покупок: более 130 тысяч товаров разных категорий, удобные способы оплаты и доставки.',
#   'icon': 'http://ulmart.ruresources/i/ulmart-logo-app90.png'},
#  {'domain': 'posudaok.ru',
#   'countInSerm': 127,
#   'isExcluded': False,
#   'sqi': [350],
#   'isOfferDomain': False,
#   'sqiDiff': 0.7,
#   'title': 'Лучшая посуда для ресторана, бара, кафе и дома в posudaok.ru.',
#   'description': 'Купить профессиональную посуду для ресторана, бара, кафе и для дома',
#   'icon': 'http://posudaok.ru/favicon.ico'},
#  {'domain': 'bakerstore.ru',
#   'countInSerm': 124,
#   'isExcluded': False,
#   'sqi': [500],
#   'isOfferDomain': False,
#   'sqiDiff': 1,
#   'title': '\n\t\tBaker Store - магазин для кондитеров.  Товары для кондитеров в СПБ и Москве\t',
#   'description': 'В магазине для кондитеров Baker Store вы найдете все необходимые товары для кондитеров в Санкт-Петербурге и Москве. ',
#   'icon': 'https://bakerstore.ru/image/catalog/favico.gif'},
#  {'domain': 'korablik.ru',
#   'countInSerm': 123,
#   'isExcluded': True,
#   'sqi': [5400],
#   'isOfferDomain': False,
#   'sqiDiff': 10.8,
#   'title': '',
#   'description': '',
#   'icon': 'http://korablik.ru/favicon.ico'},
#  {'domain': 'samura-online.ru',
#   'countInSerm': 122,
#   'isExcluded': True,
#   'sqi': [240],
#   'isOfferDomain': False,
#   'sqiDiff': 0.48,
#   'title': 'Кухонные ножи, купить в магазине SAMURA',
#   'description': 'Качественные кухонные ножи производства Япония. В нашем ассортименте вы можете выбрать и купить кухонные ножи Samura для резки любых продуктов.',
#   'icon': 'https://samura-online.ru/image/catalog/favicon.png'},
#  {'domain': 'vazaro.ru',
#   'countInSerm': 120,
#   'isExcluded': False,
#   'sqi': [500],
#   'isOfferDomain': False,
#   'sqiDiff': 1,
#   'title': 'Магазины посуды Вазаро – изысканная кухонная, столовая посуда в Москве и Петербурге',
#   'description': 'Интернет-магазин Vazaro – продажа посуды от ведущих европейских брендов. Собственная сеть магазинов по Москве и Петербургу. Доставка почтой по России.',
#   'icon': 'http://vazaro.ru/ico/v144.png'},
#  {'domain': 'posuda7.ru',
#   'countInSerm': 118,
#   'isExcluded': False,
#   'sqi': [80],
#   'isOfferDomain': False,
#   'sqiDiff': 0.16,
#   'title': 'Интернет магазин посуды и кухонной утвари - posuda7.ru',
#   'description': 'Большой выбор посуды и кухонной утвари. Доставка курьером по Москве, почтой по России.',
#   'icon': 'http://posuda7.ru/favicon.ico'},
#  {'domain': 'maxidom.ru',
#   'countInSerm': 118,
#   'isExcluded': True,
#   'sqi': [5600],
#   'isOfferDomain': False,
#   'sqiDiff': 11.2,
#   'title': 'Максидом - интернет-магазин товаров для дома',
#   'description': 'Стройматериалы и товары для дома по лучшим ценам - в "Максидоме"!  Дизайн, строительство, ремонт дома и дачи, товары для дома.  Купить  с доставкой в Санкт-Петербурге, Нижнем Новгороде, Казани, Екатеринбурге, Самаре',
#   'icon': 'http://maxidom.ru/favicon.ico'},
#  {'domain': 'ilkitchen.ru',
#   'countInSerm': 118,
#   'isExcluded': True,
#   'sqi': [110],
#   'isOfferDomain': False,
#   'sqiDiff': 0.22,
#   'title': 'Все о кухнях - Обустройство кухни',
#   'description': 'Обустройство кухни',
#   'icon': 'http://ilkitchen.ru/favicon.ico'},
#  {'domain': 'vimall.ru',
#   'countInSerm': 117,
#   'isExcluded': True,
#   'sqi': [700],
#   'isOfferDomain': False,
#   'sqiDiff': 1.4,
#   'title': 'Vimall — поиск товаров и цен',
#   'description': 'Поиск скидок и лучшей цены в России в каталоге товаров из предложений от 21 466 интернет-магазинов.\n      ',
#   'icon': 'http://vimall.ru/favicon.ico'},
#  {'domain': 'homedorf.ru',
#   'countInSerm': 116,
#   'isExcluded': True,
#   'sqi': [180],
#   'isOfferDomain': False,
#   'sqiDiff': 0.36,
#   'title': 'Интернет-магазин Homedorf - оригинальные товары для дома и подарки по любому поводу.',
#   'description': 'В нашем магазине вы можете купить сертифицированные дизайнерские товары для дома по выгодным ценам, подарки с доставкой по Москве и всей России. Разнообразные идеи оригинальных подарков в Homedorf!',
#   'icon': 'https://homedorf.ru/images/favicon.ico'},
#  {'domain': 'magicmag.net',
#   'countInSerm': 115,
#   'isExcluded': True,
#   'sqi': [450],
#   'isOfferDomain': False,
#   'sqiDiff': 0.9,
#   'title': 'Мэджикмаг - прикольные подарки  - купить в интернет-магазине',
#   'description': '',
#   'icon': 'https://magicmag.net/image/data/Р\xa0В\xa0Р\xa0С•Р\xa0Т‘Р\xa0В¶Р\xa0ВµРЎР‚/favicon.ico.png'},
#  {'domain': 'uytterra.ru',
#   'countInSerm': 113,
#   'isExcluded': False,
#   'sqi': [190],
#   'isOfferDomain': False,
#   'sqiDiff': 0.38,
#   'title': 'Интернет-магазин Территория Уюта | Каталог товаров и цены в Москве',
#   'description': '',
#   'icon': 'http://uytterra.ru/favicon.ico'},
#  {'domain': 'bellissimacasa.ru',
#   'countInSerm': 112,
#   'isExcluded': False,
#   'sqi': [120],
#   'isOfferDomain': False,
#   'sqiDiff': 0.24,
#   'title': '\n  Товары для дома и кухни, купить товары для интерьера | Интернет-магазин Bellissima Casa     ',
#   'description': 'В интернет магазине Беллиссима Каза вы можете купить эксклюзивные товары для дома и кухни. Bellissima Casa гарантирует покупку подлинной брендовой продукции по доступной цене в Москве, не выходя из дома. Доставка по Москве и всей России.',
#   'icon': 'http://bellissimacasa.ru/i/icon_bella.png'},
#  {'domain': 'tvoydom.ru',
#   'countInSerm': 111,
#   'isExcluded': True,
#   'sqi': [1900],
#   'isOfferDomain': False,
#   'sqiDiff': 3.8,
#   'title': '\nТвой Дом\n    ',
#   'description': '',
#   'icon': 'http://tvoydom.ru/favicon.ico?id=9'},
#  {'domain': 'megaterem.ru',
#   'countInSerm': 111,
#   'isExcluded': False,
#   'sqi': [300],
#   'isOfferDomain': False,
#   'sqiDiff': 0.6,
#   'title': 'Интернет-магазин товаров для дома МегаТерем | Каталог товаров и цены',
#   'description': '',
#   'icon': 'http://megaterem.ru/favicon.ico'},
#  {'domain': 'tut-posuda.ru',
#   'countInSerm': 111,
#   'isExcluded': False,
#   'sqi': [30],
#   'isOfferDomain': False,
#   'sqiDiff': 0.06,
#   'title': 'Интернет-магазин кухонной посуды "Тут Посуда"',
#   'description': '',
#   'icon': 'http://tut-posuda.ru/favicon.ico'},
#  {'domain': 'posudacenter.ru',
#   'countInSerm': 109,
#   'isExcluded': False,
#   'sqi': [1800],
#   'isOfferDomain': False,
#   'sqiDiff': 3.6,
#   'title': 'Посуда Центр - интернет-магазин товаров для кухни, дома и отдыха',
#   'description': 'В интернет-магазине Посуда Центр большой выбор товаров для дома, дачи и отдыха. Скидки, бонусная программа и отличные цены. Удобные оплата и доставка.',
#   'icon': 'http://posudacenter.ru/favicon.ico?1560490506'},
#  {'domain': 'womanadvice.ru',
#   'countInSerm': 108,
#   'isExcluded': True,
#   'sqi': [7000],
#   'isOfferDomain': False,
#   'sqiDiff': 14,
#   'title': 'Женский журнал WomanAdvice.ru - советы на все случаи жизни',
#   'description': '',
#   'icon': 'http://womanadvice.ru/sites/all/themes/womanadvice/favicon.ico'},
#  {'domain': 'kitchen-profi.ru',
#   'countInSerm': 107,
#   'isExcluded': False,
#   'sqi': [300],
#   'isOfferDomain': False,
#   'sqiDiff': 0.6,
#   'title': 'Интернет-магазин европейской посуды для кухни Kitchen Profi - дорогая эксклюзивная посуда, купить в Москве, Санкт-Петербурге',
#   'description': 'Дизайнерская посуда для кухни от лучших европейских брендов с доставкой. Каталог в интернет-магазине элитной посуды. Описания, характеристики и актуальные цены. Скидки и акции!',
#   'icon': 'https://kitchen-profi.ru/image/data/favicon.png'},
#  {'domain': 'td-tnp.ru',
#   'countInSerm': 105,
#   'isExcluded': True,
#   'sqi': [220],
#   'isOfferDomain': False,
#   'sqiDiff': 0.44,
#   'title': 'Интернет-магазин «Товары народного потребления»',
#   'description': 'Интернет-магазин «Товары народного потребления». У нас более 7000 наименований продукции от крупнейших производителей. Сотрудничаем с оптовыми и розничными покупателями. Более 12 лет успешной работы. Доставка по всей России.',
#   'icon': 'http://td-tnp.ru/favicon.ico'},
#  {'domain': 'kluk.ru',
#   'countInSerm': 105,
#   'isExcluded': False,
#   'sqi': [60],
#   'isOfferDomain': False,
#   'sqiDiff': 0.12,
#   'title': '\n    Кухонная утварь, купить кухонные принадлежности в интернет-магазине посуды KLUK    ',
#   'description': 'Интернет-магазин KLUK.ru предлагает большой выбор кухонных принадлежностей. Продукция известных производителей по невысокой цене. Оперативная доставка.',
#   'icon': 'http://kluk.ru/favicon.ico'},
#  {'domain': 'kastrylki.ru',
#   'countInSerm': 105,
#   'isExcluded': False,
#   'sqi': [100],
#   'isOfferDomain': False,
#   'sqiDiff': 0.2,
#   'title': 'Кастрюльки.Ру | Купить посуду в интернет магазине | Кухонная посуда интернет магазин',
#   'description': '',
#   'icon': 'http://kastrylki.ru/favicon.ico'},
#  {'domain': '4fresh.ru',
#   'countInSerm': 105,
#   'isExcluded': True,
#   'sqi': [2200],
#   'isOfferDomain': False,
#   'sqiDiff': 4.4,
#   'title': '4fresh.ru – интернет-магазин натуральных товаров – Купить живую органическую косметику ручной работы в Москве',
#   'description': 'Первый мультибрендовый интернет-магазин натуральной косметики и органической косметики ручной работы. Подобрать и купить именно то, что Вам необходимо поможет on-line консультация косметолога и отзывы Клиентов.',
#   'icon': 'http://4fresh.ru/favicon.ico'},
#  {'domain': 'posudaserviz.ru',
#   'countInSerm': 104,
#   'isExcluded': False,
#   'sqi': [350],
#   'isOfferDomain': False,
#   'sqiDiff': 0.7,
#   'title': 'Купите фарфоровую посуду, столовые сервизы в интернет-магазине Гранд Престиж',
# ...
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [350],
#   'isOfferDomain': False,
#   'sqiDiff': 0.7,
#   'title': 'Твой Поваренок - Пошаговые рецепты, кулинарные советы, мануалы по кухонной технике',
#   'description': 'Пошаговые рецепты, кулинарные советы, мануалы по кухонной технике',
#   'icon': 'http://tvoi-povarenok.ru/favicon.ico'},
#  {'domain': 'kuhnya-tehnika.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [120],
#   'isOfferDomain': False,
#   'sqiDiff': 0.24,
#   'title': 'KitchenStuff - Рейтинг лучшей бытовой и кухонной техники. Обзоры, отзывы, сравнения фирм и производителей.',
#   'description': 'Рейтинг лучшей бытовой и кухонной техники. Обзоры, отзывы, сравнения фирм и производителей.',
#   'icon': 'http://kuhnya-tehnika.ru//kuhnya-tehnika.ru/wp-content/themes/ks/i/favicon.ico'},
#  {'domain': 'kupilsumom.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [230],
#   'isOfferDomain': False,
#   'sqiDiff': 0.46,
#   'title': 'Рейтинги и обзоры товаров',
#   'description': '',
#   'icon': 'https://kupilsumom.ru/wp-content/uploads/2018/05/favicon.ico'},
#  {'domain': 'kwatro.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [300],
#   'isOfferDomain': False,
#   'sqiDiff': 0.6,
#   'title': 'Kwatro.ru интернет-магазин',
#   'description': '',
#   'icon': 'http://kwatro.ru/favicon.ico'},
#  {'domain': '1chef.ru',
#   'countInSerm': 7,
#   'isExcluded': False,
#   'sqi': [40],
#   'isOfferDomain': False,
#   'sqiDiff': 0.08,
#   'title': 'Интернет-магазин посуды для кухни в Москве. ШЕФ - главный по кухне',
#   'description': 'Магазин посуды для кухни в Москве. 1chef.ru - большой выбор сковородок, ножей, кухонных аксессуаров. Доставка по всей России.',
#   'icon': 'http://1chef.ru/favicon.ico?1511832419'},
#  {'domain': 'hozsumka.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [70],
#   'isOfferDomain': False,
#   'sqiDiff': 0.14,
#   'title': 'Сумки оптом от производителя - дёшево в Москве | Хозяйственные баулы',
#   'description': 'Вы можете заказать хозяйственные сумки баулы за дёшево в Москве, на сайте нашего интернет-магазина «ХозСумки»',
#   'icon': 'http://hozsumka.ru/favicon.ico'},
#  {'domain': 'dirox.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [600],
#   'isOfferDomain': False,
#   'sqiDiff': 1.2,
#   'title': 'Интернет-магазин товаров для дома, спорта и отдыха',
#   'description': '',
#   'icon': 'http://dirox.ru/local/templates/dirox/img/favicon/apple-touch-icon-57x57.png'},
#  {'domain': 'mircoffee.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [110],
#   'isOfferDomain': False,
#   'sqiDiff': 0.22,
#   'title': 'Интернет магазин кофемашин и кофемолок | Купить кофемашину в интернет магазине "Мир Кофе"',
#   'description': 'Интернет магазин кофемашин и кофемолок ',
#   'icon': 'http://mircoffee.rufavicon.ico'},
#  {'domain': 'laminatepol.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [150],
#   'isOfferDomain': False,
#   'sqiDiff': 0.3,
#   'title': 'Крупнейший сайт о напольных покрытиях',
#   'description': 'Добро пожаловать на наш сайт !! Ремонт и обновление квартиры требует подбора самого долговечного, надежного и практичного напольного покрытия, и всем этим',
#   'icon': 'http://laminatepol.ru/favicon.ico'},
#  {'domain': 'kitfort.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [350],
#   'isOfferDomain': False,
#   'sqiDiff': 0.7,
#   'title': 'Официальный сайт "KITFORT"  – интернет-магазин бытовой техники',
#   'description': 'Продажа бытовой техники по доступным ценам. Большой выбор качественных товаров для для кухни и дома.',
#   'icon': 'http://kitfort.ru/favicon.ico'},
#  {'domain': 'p-td.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [750],
#   'isOfferDomain': False,
#   'sqiDiff': 1.5,
#   'title': 'Торговый Дом «Петровский»: посуда, хозтовары, пластик оптом',
#   'description': 'ООО «Петровский» Т.Д. предлагает широкий ассортимент хозтоваров и посуды. Подробности можно узнать по бесплатному телефону 8-800-555-17-05.',
#   'icon': 'http://p-td.ru/local/templates/p-td/icons/favicon.ico'},
#  {'domain': 'tesaki.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [40],
#   'isOfferDomain': False,
#   'sqiDiff': 0.08,
#   'title': 'Магазин ножей Tesaki.ru в Москве – купить лучшие ножи дешево с доставкой по РФ',
#   'description': 'Магазин ножей в Москве Tesaki.ru предлагает более трех десятков видов ножей, аксессуары и посуду. У нас вы сможете купить лучший нож для кухонных, охотничьих, туристических или прочих целей',
#   'icon': 'http://tesaki.ru/favicon.ico'},
#  {'domain': 'gorzdrav.org',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [2300],
#   'isOfferDomain': False,
#   'sqiDiff': 4.6,
#   'title': 'Интернет-аптека Горздрав: купить лекарства по низким ценам в Москве, наличие и поиск препаратов в онлайн аптеке на официальном сайте',
#   'description': 'Горздрав — поиск лекарств в Москве. Вы можете купить лекарственные средства, найти подробные инструкции по применению и отзывы о препаратах. Весь товар сертифицирован.',
#   'icon': 'http://gorzdrav.org/_ui/responsive/common/images/favicon/gorzdrav/favicon-32x32.png'},
#  {'domain': 'leonardohobby.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [3000],
#   'isOfferDomain': False,
#   'sqiDiff': 6,
#   'title': 'Интернет-магазин товаров для рукоделия и творчества "Леонардо"',
#   'description': '',
#   'icon': 'http://leonardohobby.ru//leonardo.ru/favicon.png'},
#  {'domain': 'fishki.net',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [34000],
#   'isOfferDomain': False,
#   'sqiDiff': 68,
#   'title': 'Fishki.net - Сайт хорошего настроения',
#   'description': 'Приколы, юмор, шутки, смешные фото и видео для хорошего настроения на развлекательном портале Fishki.net',
#   'icon': 'http://fishki.net//cdn.fishki.net/favicon_fishki.ico'},
#  {'domain': 'bamboopro.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [20],
#   'isOfferDomain': False,
#   'sqiDiff': 0.04,
#   'title': 'Бамбук в современном мире',
#   'description': 'Уникальное растение бамбука его применение в различных сферах человеческой деятельности в современном мире',
#   'icon': 'https://bamboopro.ru/favicon.ico'},
#  {'domain': 'veshnyaki-um.com',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [20],
#   'isOfferDomain': False,
#   'sqiDiff': 0.04,
#   'title': 'Универсальный магазин "Вешняки". Москва',
#   'description': '',
#   'icon': 'http://veshnyaki-um.com/favicon.ico'},
#  {'domain': 'informat.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [900],
#   'isOfferDomain': False,
#   'sqiDiff': 1.8,
#   'title': 'Купить канцтовары в интернет-магазине inФОРМАТ, товары для офиса оптом и в розницу с доставкой по Москве и другим городам России.',
#   'description': 'Интернет-магазин inФОРМАТ предлагает купить канцтовары для дома и офиса по выгодной цене с доставкой. На сайте представлен широкий ассортимент недорогих  канцелярских товаров. Продажа оптом и в розницу. Оформить заказ можно онлайн. Доставка по Москве и всей России.',
#   'icon': 'http://informat.ru/favicon.ico'},
#  {'domain': 'magazin-zamki.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [140],
#   'isOfferDomain': False,
#   'sqiDiff': 0.28,
#   'title': 'МАГАЗИН "ЗАМКИ" - Магазин замков и дверной фурнитуры в Белгороде',
#   'description': 'Магазин замков и дверной фурнитуры в Белгороде. Более 6000 наименований. ул. Дегтярева 2а, тел. 75-22-77 (р-он Водстроя). Врезные, накладные, навесные, кодовые, электромеханические, сейфовые замки, дверные ручки, петли, цилиндры, шпингалеты, доводчики и т.д.',
#   'icon': 'http://magazin-zamki.ru/wp-content/uploads/2015/10/20620012401511254.jpg'},
#  {'domain': 'appliances.oksar.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [700],
#   'isOfferDomain': False,
#   'sqiDiff': 1.4,
#   'title': 'Бытовая техника - купить мелкую и крупную технику для дома, кухни в Москве по выгодной цене на Оксаре. Продажа, подбор и сравнение по характеристикам.',
#   'description': 'Купить бытовую технику по низким ценам - актуальное наличие, помощь при выборе и заказе. Доставим мелкую и крупную технику для дома, кухни в срок! Оксар &#9742; 8-800-555-22-57.',
#   'icon': 'http://appliances.oksar.ru/images/favicon.png'},
#  {'domain': 'bestvix.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [130],
#   'isOfferDomain': False,
#   'sqiDiff': 0.26,
#   'title': 'BestVix - рейтинги, обзоры, новинки',
#   'description': 'Мы подобрали для вас лучшие модели товаров и составили рейтинг. Если вы сомневаетесь в выборе, расскажем по каким критериям нужно выбирать и на какие характеристики модели полагаться при выборе.',
#   'icon': 'https://bestvix.ru/wp-content/uploads/2018/11/favicon.png'},
#  {'domain': 'bulat.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [110],
#   'isOfferDomain': False,
#   'sqiDiff': 0.22,
#   'title': 'Магазин ножей Булат в Москве. Купить нож с доставкой.',
#   'description': 'Интернет-магазин ножей ',
#   'icon': 'http://bulat.ru/apple-touch-icon.png'},
#  {'domain': 'ac-studio.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [250],
#   'isOfferDomain': False,
#   'sqiDiff': 0.5},
#  {'domain': 'posuda-pro.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [110],
#   'isOfferDomain': False,
#   'sqiDiff': 0.22,
#   'title': 'Оптовая продажа посуды для баров и ресторанов в Воронеже :: Посуда PRO',
#   'description': '«Посуда PRO» – это комплексное оснащение ресторанов, баров, кафе, гостиниц и иных заведений общественного питания. Вот уже более десяти лет наша компания специализируется на оптовых продажах посуды.',
#   'icon': 'http://posuda-pro.ru/favicon.ico'},
#  {'domain': 'moskva.kubansteklotara.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [250],
#   'isOfferDomain': False,
#   'sqiDiff': 0.5,
#   'title': 'Пластиковая и стеклянная тара 💎 крышки и закаточные машинки по оптовым ценам в Москве 👉 с доставкой по России',
#   'description': 'Компания «КубаньСтеклоТара» ✨ предлагает пластиковую и стеклянную тару, изделия из ПЭТ, крышки и закаточные машинки  ⭐ ️.⭐ ️.⭐ ️.⭐ ️.⭐ ️ оптом в Москве 💲 с доставкой по России в интернет-магазине.',
#   'icon': 'http://moskva.kubansteklotara.ru/favicon.ico'},
#  {'domain': 'dekor-td.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [110],
#   'isOfferDomain': False,
#   'sqiDiff': 0.22,
#   'title': 'Фартук для кухни - купить в СПб | Цена на кухонные фартуки с фотопечатью',
#   'description': 'Кухонные панели фартуки скинали: МДФ, АБС пластик, закаленное стекло с фотопечатью недорого - продажа в Санкт-Петербурге от ТД Декор. Каталог, фото, цена. Также в нашем интернет-магазине можно купить фартуки для кухни из нержавейки, интерьерные картины и 3D-панели из МДФ, настенные часы.',
#   'icon': 'http://dekor-td.ru/favicon.ico?1560761022'},
#  {'domain': 'eradetstva.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [160],
#   'isOfferDomain': False,
#   'sqiDiff': 0.32,
#   'title': 'Интернет-магазин детских игрушек и товаров для детей предлагает купить игрушки: мягкие игрушки, куклы, настольные игры',
#   'description': 'В интернет-магазине вы всегда можете купить мягкие игрушки, куклы, радиоуправляемые игрушки',
#   'icon': 'http://eradetstva.ru/favicon.ico'},
#  {'domain': 'justbutik.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [750],
#   'isOfferDomain': False,
#   'sqiDiff': 1.5,
#   'title': 'Justbutik – поиск одежды, обуви и аксессуаров всех брендов и магазинов | Justbutik',
#   'description': 'Удобный, бесплатный и быстрый поиск по российским интернет-магазинам. Сделать покупку в два клика стало реальностью.',
#   'icon': 'http://justbutik.ru/favicon.ico'},
#  {'domain': 'opamuurikka.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [90],
#   'isOfferDomain': False,
#   'sqiDiff': 0.18},
#  {'domain': 'ergotronica.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [400],
#   'isOfferDomain': False,
#   'sqiDiff': 0.8,
#   'title': 'Официальный сайт Эрготроника; Интернет магазин удобной и эргономичной мебели; Шоу рум в Москве, доставка по России.',
#   'description': 'Интернет-магазин классной, удобной, стильной и эргономичной мебели "Эрготроника" - это уникальный для Москвы и России проект. У нас вы можете купить практические любые кресла от недорогих, до элитных.',
#   'icon': 'http://ergotronica.ru/assets/img/icon-16x16.png'},
#  {'domain': 'dekorum-vd.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [90],
#   'isOfferDomain': False,
#   'sqiDiff': 0.18,
#   'title': '«Декорум в доме» - прозрачная скатерть для мебели и скатертей в Москве  ',
#   'description': 'Прозрачная скатерть (мягкое стекло): изящество, надёжность и практичная защита вашей мебели! Купить в Москве с доставкой по России ☎ 8(926)810-35-07; ☎ 8(977)587-01-28.',
#   'icon': 'http://dekorum-vd.ru/favicon.ico'},
#  {'domain': 'spark-interfax.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [3600],
#   'isOfferDomain': False,
#   'sqiDiff': 7.2,
#   'title': 'СПАРК — Проверка контрагента, узнать сведения об организации по ИНН, анализ рынка в системе СПАРК-Интерфакс',
#   'description': '✓ Проверка контрагента в системе ★СПАРК★ — получите актуальные и полные сведения о контрагенте онлайн. ➤ Проявите должную осмотрительность и оцените риски по 40 факторам. ⤇ Бесплатный демо-доступ, звоните ☎ +7 (495) 787-43-43',
#   'icon': 'http://spark-interfax.ru/Content/images/favicon/apple-touch-icon-76x76.png'},
#  {'domain': 'konditer-tools.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [10],
#   'isOfferDomain': False,
#   'sqiDiff': 0.02,
#   'title': 'Инструменты и инвентарь для кондитера интернет магазин konditer-tools.ru ',
#   'description': 'Интернет магазин konditer-tools.ru предлагает приобрести украшения и оформление для тортов, а также различный инвентарь и инструменты для кондитера по самым низким ценам ',
#   'icon': 'http://konditer-tools.ru/favicon.png'},
#  {'domain': 'zakupka.com',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [3800],
#   'isOfferDomain': False,
#   'sqiDiff': 7.6,
#   'title': 'Zakupka.com - каталог интернет-магазинов, товаров, услуг и цен Украины',
#   'description': '165 000 интернет-магазинов, 14 860 000 товаров и 68 000 услуг Украины с актуальными ценами. Крупнейший каталог сайтов товаров и услуг - Zakupka.com',
#   'icon': 'http://zakupka.com/pics/favicons/apple-icon-57x57.png'},
#  {'domain': 'loopy.ru',
#   'countInSerm': 7,
#   'isExcluded': True,
#   'sqi': [2300],
#   'isOfferDomain': False,
#   'sqiDiff': 4.6,
#   'title': 'Поиск слов по маске и определению, сканворд дня, кроссворды онлайн',
#   'description': 'Поиск слов по маске и определению, помощник кроссвордиста, разгадывание сканвордов и кроссвордов онлайн, словарь кроссвордиста',
#   'icon': 'http://loopy.ru/favicon.ico'},
#  {'domain': 'oasiscatalog.com',
#   'countInSerm': 6,
#   'isExcluded': True,
#   'sqi': [1100],
#   'isOfferDomain': False,
#   'sqiDiff': 2.2,
#   'title': 'Oasis - сувенирная продукция с логотипом компании, корпоративные подарки и бизнес сувениры оптом',
#   'description': 'Бизнес-подарки, сувениры и промо продукция оптом. Oasis - ведущий поставщик подарков под нанесение логотипа в РФ с собственным производством, складами в России и Европе.',
#   'icon': 'http://oasiscatalog.com/apple-touch-icon.png'},
#  {'domain': 'fanilla.net',
#   'countInSerm': 6,
#   'isExcluded': False,
#   'sqi': [20],
#   'isOfferDomain': False,
#   'sqiDiff': 0.04},
#  {'domain': 'housechief.ru',
#   'countInSerm': 6,
#   'isExcluded': True,
#   'sqi': [1000],
#   'isOfferDomain': False,
#   'sqiDiff': 2,
#   'title': 'HouseChief.ru - online-издание для современных мастеров',
#   'description': 'Ежедневные статьи о мире строительства и дизайна с пошаговыми инструкциями и практическими советами, фото- и видео-подборками, полезными сервисами для строителей и домашних мастеров.',
#   'icon': 'https://housechief.ru/wp-content/uploads/2019/02/favicon_chief.png'},
#  {'domain': 'fruit-basket.ru',
#   'countInSerm': 6,
#   'isExcluded': True,
#   'sqi': [20],
#   'isOfferDomain': False,
#   'sqiDiff': 0.04,
#   'title': 'Заказать фруктовые корзины в Москве в подарок',
#   'description': 'Дизайн-мастерская "Фруктовая Корзина" работает с 2012 года. Вы можете изменить состав в любой фруктовой корзине, добавить любые фрукты, конфеты или алкоголь. Доставляем по Москве и МО, звоните!',
#   'icon': 'https://static.tildacdn.com/tild6539-3264-4366-b265-356237393164/favicon.ico'},
#  ...]

# %%
all_keywords = getKeywordsRivals(keywords, rivals, maxPos, startDate, keywordsStr, regionsStr, regions, minCountInSerm)
all_keywords
# Out:
# ---------------------------------------------------------------------------
# ServerException                           Traceback (most recent call last)
# <ipython-input-147-6f7f405ecda6> in <module>()
# ----> 1 all_keywords = getKeywordsRivals(keywords, rivals, maxPos, startDate, keywordsStr, regionsStr, regions, minCountInSerm)
#       2 all_keywords
#
# ~/Demin/rivals-seo-offer-vuejs/backend_logic.py in getKeywordsRivals(keywords, rivals, maxPos, startDate, keywordsStr, regionsStr, regions, minCountInSerm)
#     260         having time=max(time)
#     261         order by count(*) desc
# --> 262     """
#     263     print(query)
#     264     client = Client(host = '192.168.10.101', user = 'read_only', password = 'User_ro')
#
# ~/anaconda2/envs/py35/lib/python3.6/site-packages/clickhouse_driver/client.py in execute(self, query, params, with_column_types, external_tables, query_id, settings, types_check, columnar)
#     117                     external_tables=external_tables,
#     118                     query_id=query_id, types_check=types_check,
# --> 119                     columnar=columnar
#     120                 )
#     121
#
# ~/anaconda2/envs/py35/lib/python3.6/site-packages/clickhouse_driver/client.py in process_ordinary_query(self, query, params, with_column_types, external_tables, query_id, types_check, columnar)
#     190                                              types_check=types_check)
#     191         return self.receive_result(with_column_types=with_column_types,
# --> 192                                    columnar=columnar)
#     193
#     194     def iter_process_ordinary_query(
#
# ~/anaconda2/envs/py35/lib/python3.6/site-packages/clickhouse_driver/client.py in receive_result(self, with_column_types, progress, columnar)
#      40                 gen, with_column_types=with_column_types, columnar=columnar
#      41             )
# ---> 42             return result.get_result()
#      43
#      44     def iter_receive_result(self, with_column_types=False):
#
# ~/anaconda2/envs/py35/lib/python3.6/site-packages/clickhouse_driver/result.py in get_result(self)
#      37
#      38     def get_result(self):
# ---> 39         for packet in self.packet_generator:
#      40             self.store(packet)
#      41
#
# ~/anaconda2/envs/py35/lib/python3.6/site-packages/clickhouse_driver/client.py in packet_generator(self)
#      52         while True:
#      53             try:
# ---> 54                 packet = self.receive_packet()
#      55                 if not packet:
#      56                     break
#
# ~/anaconda2/envs/py35/lib/python3.6/site-packages/clickhouse_driver/client.py in receive_packet(self)
#      69
#      70         if packet.type == ServerPacketTypes.EXCEPTION:
# ---> 71             raise packet.exception
#      72
#      73         elif packet.type == ServerPacketTypes.PROGRESS:
#
# ServerException: Code: 62.
# DB::Exception: Syntax error: failed at position 262136 (line 9, col 43277): 'delaemrukami.org', 'finmarket.moscow', 'jtcrussia.ru', 'winecellar.ru', 'ecodoma.ru', 'newbar.ru', 'catndogshop.ru', 'casual-info.ru', 'elposuda.ru', 'bodyline. Max query size exceeded. Stack trace:
#
# 0. /usr/bin/clickhouse-server(StackTrace::StackTrace()+0x16) [0x56d06c6]
# 1. /usr/bin/clickhouse-server(DB::Exception::Exception(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, int)+0x22) [0x2da2d92]
# 2. /usr/bin/clickhouse-server(DB::parseQuery(DB::IParser&, char const*, char const*, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, unsigned long)+0xac) [0x569595c]
# 3. /usr/bin/clickhouse-server() [0x4ef52b3]
# 4. /usr/bin/clickhouse-server(DB::executeQuery(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, DB::Context&, bool, DB::QueryProcessingStage::Enum)+0x8a) [0x4ef646a]
# 5. /usr/bin/clickhouse-server(DB::TCPHandler::runImpl()+0x3d7) [0x2daf907]
# 6. /usr/bin/clickhouse-server(DB::TCPHandler::run()+0x2b) [0x2db07ab]
# 7. /usr/bin/clickhouse-server(Poco::Net::TCPServerConnection::start()+0xf) [0x58c510f]
# 8. /usr/bin/clickhouse-server(Poco::Net::TCPServerDispatcher::run()+0x16a) [0x58c54ea]
# 9. /usr/bin/clickhouse-server(Poco::PooledThread::run()+0x77) [0x59668f7]
# 10. /usr/bin/clickhouse-server(Poco::ThreadImpl::runnableEntry(void*)+0x38) [0x59627b8]
# 11. /usr/bin/clickhouse-server() [0x930310f]
# 12. /lib/x86_64-linux-gnu/libpthread.so.0(+0x7494) [0x7f65093bf494]
# 13. /lib/x86_64-linux-gnu/libc.so.6(clone+0x3f) [0x7f6508bf9acf]

# %%
minKeywordRivals = 9
keywordsToDelete = getKeywordsToRemove(all_keywords, minKeywordRivals, regions)

# %%
keywordsToDeleteForExcel
# Out:
# [{'Регион': 'Москва', 'Ключ для удаления': 'виниловая пленка под карбон'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'стоимость оклейки машины пленкой'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка самоклеющаяся для машины'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'винил 3м'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обтянуть машину винилом'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка машины виниловой пленкой цена в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка карбон на авто цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'бронирование автомобилей пленкой цена в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленки самоклеющиеся для авто'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'продажа виниловой пленки для авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'полная оклейка автомобилей'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'купить пленку для оклейки машины'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'перетянуть авто пленкой цена москва'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка автомобиля виниловой пленкой цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'пленка для автомобиля карбон цвета и цены'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'плёнка карбон купить в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'винил на белом авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка винил купить в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'виниловая оклейка автомобилей'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка 3м'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка кузова автомобиля пленкой цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'сколько стоит обтянуть машину винилом'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка карбон цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'поклейка винила на авто цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка под карбон'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машины цветной пленкой'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'виниловая пленка для авто купить в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'винил пленка купить'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'виниловая пленка для оклейки авто купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'карбон для авто купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обклейка машины цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка авто пленкой цены в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'виниловая пленка для авто цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'полная оклейка авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'бронирование пленкой цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'автовинил карбон'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка 3m для автомобиля'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка 3m'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка три м'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'винил на авто цена москва'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка авто пленкой'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'карбоновая пленка цена за 1 метр'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'купить пленку карбон для автомобиля'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка дисков пленкой цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'пленка карбон на авто цена расцветка'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'белый автовинил на авто'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'автовинил купить в москве адреса магазинов'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'карбон на машину цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'автомобильная пленка 3м'},
#  {'Регион': 'Москва', 'Ключ для удаления': '3m винил'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'покрытие авто пленкой цена москва'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'коричневый карбон'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'купить карбоновую пленку'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'автомобильный винил'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'карбон цена за 1 метр'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'купить пленку 3м в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машин в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обклеить машину винилом'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'винил на авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'купить пленку 3 м'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машины'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка карбон на авто купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'виниловая пленка карбон'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обтяжка дисков пленкой цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машины винилом цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка виниловой пленкой авто цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'виниловая пленка для авто купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка кузова винилом'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'сколько стоит карбоновая пленка на машину цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'продажа виниловой пленки для оклейки авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машины виниловой пленкой'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'купить автомобильную пленку'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка на машину купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка винилом в москве цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'купить винил для автомобиля'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка авто виниловой пленкой'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обтянуть винилом машину цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка 3м для авто купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'винил под карбон'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка машины пленкой цена в москве'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'винил пленка для авто купить в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка автомобиля цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'карбон стоимость'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'автовинил дешево купить'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'купить карбоновую пленку в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машины пленкой цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'автопленка купить'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'обтяжка виниловой пленкой авто цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка машины виниловой пленкой цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка авто винилом'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'купить пленку для оклейки автомобиля в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'виниловая оклейка авто цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'карбоновая пленка для авто купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка автовинил'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машины винилом'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обтяжка винилом авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка кузова автомобиля'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка пленкой авто в москве'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка авто пленкой цены в москве дешево'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машины пленкой'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'купить пленку для оклейки автомобиля'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка м3'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обтяжка машины винилом'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка под карбон для автомобиля'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'карбоновые пленки для автомобиля купить'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка автомобиля виниловой пленкой'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'бронирование автомобилей пленкой цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'полная оклейка автомобиля пленкой'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка авто винилом цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'стоимость оклейки авто винилом'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'купить пленка 3м для авто купить в'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машины пленкой в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка авто пленкой дешево цены'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'стоимость оклейки авто виниловой пленкой цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'купить виниловую пленку для автомобиля в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'купить автовинил недорого'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка машины прозрачной пленкой'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'пленка для автомобиля купить в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'покрыть машину винилом'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'самоклеющаяся пленка для автомобиля купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'заказать пленку автовинил'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'стоимость оклейки авто пленкой'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'пленки для оклейки автомобилей каталог'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка под карбон купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обтяжка винилом авто цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'автовинил на авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'винил на машину цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'стоимость оклейки машины'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'обклеить машину зеркальной пленкой цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'виниловая оклейка авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка 3м для авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'автовинил оклейка авто цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка авто матовой пленкой цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка кузова автомобиля пленкой'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка машин цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'обклеить машину пленкой цена москва с фото'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'купить виниловую пленку для автомобиля'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'стоимость оклейки автомобиля пленкой'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка карбон купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'винил на черном авто'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка авто в москве'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка дисков пленкой цена в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'виниловая пленка для авто 3м'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'сколько стоит оклейка автомобиля виниловой пленкой'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'карбон на авто цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обтяжка автомобилей винилом'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'карбоновая пленка для авто купить в москве'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'купить автомобильную пленку в москве'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'виниловая пленка под карбон купить'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'пленки автомобильные самоклеющиеся'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'стоимость оклейки авто пленкой в москве качественно'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'виниловая пленка купить'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'полная оклейка автомобиля пленкой цена'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'обклеить машину винилом цена в москве'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка автомобиля'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'оклейка автомобиля в москве'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'оклейка цветной пленкой автомобиля'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'виниловая оклейка автомобилей цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'виниловая пленка купить в москве'},
#  {'Регион': 'Москва',
#   'Ключ для удаления': 'стоимость оклейки авто виниловой пленкой'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка 3 м автомобильная'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'карбоновая пленка для авто цена'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'пленка 3m купить'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'обтяжка винилом'},
#  {'Регион': 'Москва', 'Ключ для удаления': 'карбоновый винил'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'наклейки на черную машину'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'наклейки на автомобиль каталог'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'купить виниловые наклейки на авто'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'наклейки на авто каталог'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'наклейки на авто винил'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'купить наклейки на кузов автомобиля'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'виниловые наклейки на машину'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'наклейки на черное авто'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'наклейки на авто маленькие'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'наклейки на кузов авто'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'купить стикеры на машину'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'наклейки на кузов автомобиля'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'большие наклейки на авто цветные'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'цветные наклейки на машину'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'виниловые наклейки на машину на заказ'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'большие наклейки на машины'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'купить автонаклейки'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'виниловые наклейки на авто'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'виниловые наклейки на авто на заказ'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'автонаклейки на машину купить интернет магазин'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'виниловые наклейки на авто москва'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'наклейка в виде авто на авто'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'наклейка виниловых наклеек на авто'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'виниловые наклейки на автомобиль купить'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'виниловые наклейки на авто на заказ москва'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'виниловые наклейки на авто купить в москве'},
#  {'Регион': 'Все регионы', 'Ключ для удаления': 'цветные наклейки на авто'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'наклейки на авто черно белые'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'цветные виниловые наклейки на авто'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'наклейки на авто больших размеров'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'дизайнерские наклейки на авто'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'виниловые наклейки на автомобиль'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'оригинальные наклейки на машину'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'купить автонаклейки в москве'},
#  {'Регион': 'Все регионы',
#   'Ключ для удаления': 'наклейки на авто оригинальные'}]

# %%
test = exportToExcel(offerid, maxRivalsCount, sqiDiffCoef, maxPos, minCountInSerm, minKeywordRivals, keywordsToDelete, regions, rivals, all_keywords)
test
# Out:
# '5cf13d257e76804174c3bc4b.xlsx'

# %%
def exportToExcel(offerid, maxRivalsCount, sqiDiffCoef, maxPos, minCountInSerm, minKeywordRivals, keywordsToDelete, regions, rivals, all_keywords):
    fileName = offerid+'.xlsx'
    info = [{
        'Id КП': offerid,
        'Макс. кол-во конкурентов': maxRivalsCount,
        'Макс. отклонение ИКС': sqiDiffCoef,
        'Макс. позиция для поиска конкурентов': maxPos,
        'Мин. кол-во раз, сколько сайт должен встречаться в выдаче, чтобы считаться конкурентом': minCountInSerm,
        'Мин. кол-во конкурентов для запроса': minKeywordRivals
    }]
    keywordsToDeleteForExcel = []
    for item in keywordsToDelete:
        for key in item['keywordsToDelete']:
            keywordsToDeleteForExcel.append({
                'Регион': item['region'],
                'Ключ для удаления': key
            })
    writer = pd.ExcelWriter('./downloadable_files/Rivals_' + fileName)
    info_df = pd.DataFrame(info)
    info_df.to_excel(writer, index=False, sheet_name='Метаданные', freeze_panes = (1,0))
    regions_df = pd.DataFrame(regions)
    regions_df.to_excel(writer, index=False, sheet_name='Регионы', freeze_panes = (1,0))
    rivals_df = pd.DataFrame(rivals)
    rivals_df.to_excel(writer, index=False, sheet_name='Конкуренты', freeze_panes = (1,0))
    all_keywords_df = pd.DataFrame(all_keywords)
    all_keywords_df.to_excel(writer, index=False, sheet_name='Запросы', freeze_panes = (1,0))
    keywordsToDeleteForExcel_df = pd.DataFrame(keywordsToDeleteForExcel)
    keywordsToDeleteForExcel_df.to_excel(writer, index=False, sheet_name='Запросы для удаления', freeze_panes = (1,0))
    writer.save()
    return fileName

# %%
import requests
import json
import pandas as pd

url = 'http://192.168.4.158:8901/api/ExportToExcel'

req = requests.post(url, json.dumps({
    'offerUrl':'5cd19cd07e76802420b8ce98',
    'maxRivalsCount':1000,
    'sqiDiffCoef':100,
    'maxPos':10
}, ensure_ascii=False))

rivals_result = req.json()

# %%
import re
import requests
from bs4 import BeautifulSoup
domain = 'vsepodomu.ru'
sitePromise = requests.get('http://' + domain)
html = sitePromise.text
soup = BeautifulSoup(html, 'html.parser')
title = ''
description = ''
icon = 'http://' + domain + '/favicon.ico'
try:
    title = soup.select('title')[0].get_text()
except:
    pass
try:
    description = soup.find("meta", {"name":"description"})['content']
except:
    pass
try:
    icon = soup.find_all(rel = re.compile("Icon|icon"))[0]['href']
    if icon[0] != 'h':
        icon = 'http://' + domain + icon
except:
    pass
print(title)
print(description)
print(icon)
# Out:
# ВсеПоДому.ру - полезные советы по дому и хозяйству
# Все о домашнем хозяйстве. Советы по уборке дома, уходу за одеждой и обувью, чистке и выведению пятен.
# http://vsepodomu.ru“favicon.ico”

# %%
icon = soup.find_all(rel = re.compile("Icon|icon"))
icon
# Out:
# [<link href="“favicon.ico”" rel="“icon”" type="“image/x-icon”"/>]
